# %% [markdown]
# <a href="https://colab.research.google.com/github/VitasBro1/Dz-Kuzmin-Begin-Python2/blob/main/%D0%92%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D0%B5_%D0%B2_%D1%82%D0%B5%D1%85%D0%BD%D0%BE%D0%BB%D0%BE%D0%B3%D0%B8%D0%B8_%D0%98%D0%98_%D0%9A%D1%83%D0%B7%D1%8C%D0%BC%D0%B8%D0%BD_1%D0%98%D0%98_4_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = input("a:")
print(a)
# Out:
# a:67
# 67

# %%
# integer1
L = int(input("Введите L: "))
delenie = L // 100

print(delenie)
# Out:
# Введите L: 270
# 2

# %%
# integer2
M = int(input("Введите M: "))
delenie = M // 1000

print (delenie)
# Out:
# Введите M: 25000
# 25

# %%
# integer3
fail = int(input("Введите размер файла: "))
delenie = fail // 1024

print(delenie)
# Out:
# Введите размер файла: 2600
# 2

# %%
# integer4
A = int(input("Введите A: "))
B = int(input("Введите B: "))
delenie =  A // B

print(delenie)
# Out:
# Введите A: 16
# Введите B: 3
# 5

# %%
# integer5
A = int(input("Введите A: "))
B = int(input("Введите B: "))
delenie = A // B
print(A % B)
# Out:
# Введите A: 15
# Введите B: 4
# 3

# %%
# integer6
A = int(input("Введите двухзначное число: "))
B = 1
delenie = A // 10
dev =  A % 10
print(delenie)
print(dev)
# Out:
# Введите двухзначное число: 37
# 3
# 7

# %%
# integer7
A = int(input("Введите двухзначное число: "))
delenie = A // 10
dev =  A % 10
dele = delenie * dev
print(dele)
# Out:
# Введите двухзначное число: 37
# 21

# %%
# integer8
A = int(input("Введите двухзначное число: "))
delenie = A // 10
dev =  A % 10
print(f"Число: {dev}{delenie}")
# Out:
# Введите двухзначное число: 25
# Число: 52

# %%
# integer9
A = int(input("Введите трехзначное число: "))

delenie = A // 100
print(delenie)
# Out:
# Введите трехзначное число: 501
# 5

# %%
# integer10
A = int(input("Введите трехзначное число: "))
dev = A % 10
dele = A // 10 % 10
print(f"Число: {dev}{dele}")
# Out:
# Введите трехзначное число: 352
# Число: 25

# %%
# integer11
A = int(input("Введите трехзначное число: "))
delenie = A // 100
dele = A // 10 % 10
dev =  A % 10
ymnoch = dele * dev * delenie
print(ymnoch)
# Out:
# Введите трехзначное число: 352
# 30

# %%
# integer12
A = int(input("Введите трехзначное число: "))
dev = A % 10
dele = A // 10 % 10
delenie = A // 100
print(f"Число: {dev}{dele}{delenie}")
# Out:
# Введите трехзначное число: 352
# Число: 253

# %%
# integer13
A = int(input("Введите трехзначное число: "))
dev = A % 10
dele = A // 10 % 10
delenie = A // 100
print(f"Число: {dele}{dev}{delenie}")
# Out:
# Введите трехзначное число: 472
# Число: 724

# %%
# integer14
A = int(input("Введите трехзначное число: "))
dev = A % 10
dele = A // 10 % 10
delenie = A // 100
print(f"Число: {dev}{delenie}{dele}")
# Out:
# Введите трехзначное число: 572
# Число: 257

# %%
# integer15
A = int(input("Введите трехзначное число: "))
dev = A % 10
dele = A // 10 % 10
delenie = A // 100
print(f"Число: {dele}{delenie}{dev}")
# Out:
# Введите трехзначное число: 375
# Число: 735

# %%
# integer16
A = int(input("Введите трехзначное число: "))
dev = A % 10
dele = A // 10 % 10
delenie = A // 100
print(f"Число: {delenie}{dev}{dele}")
# Out:
# Введите трехзначное число: 572
# Число: 527
